# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий ревьюера:</b>
#
# Критических замечаний нет 👍 Отличная работа!
#
# Возвращаю проект, чтобы была возможность задать вопросы, если они есть)
#
# Прошу оставить их под этим комментарием.
#
# Если вопросов нет, то можешь просто вернуть проект - я его сразу зачту 👌
# </div>

# %% [markdown]
# Привет, Александр!)
# <br> Меня зовут Дуолан 👋 Буду проверять твой проект. Давай вместе доведем его до идеала 😉
# <br> Дальнейшее общение будет происходить на «ты», если это не вызывает никаких проблем.
# <br> Желательно реагировать на каждый мой комментарий («исправил», «не понятно как исправить ошибку», ...)
# <br> Пожалуйста, не удаляй мои комментарии, они будут необходимы для повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b> Если требуются исправления
# </div>
#
# Работа не может быть принята с красными комментариями.
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>

# %% [markdown]
# # Исследование оттока клиентов

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Исследование-данных" data-toc-modified-id="Исследование-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Random-forest-model" data-toc-modified-id="Random-forest-model-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Random forest model</a></span></li><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Logistic regression</a></span></li><li><span><a href="#Nearest-Neighbors" data-toc-modified-id="Nearest-Neighbors-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Nearest Neighbors</a></span></li><li><span><a href="#SVC" data-toc-modified-id="SVC-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>SVC</a></span></li></ul></li><li><span><a href="#Оптимизация" data-toc-modified-id="Оптимизация-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оптимизация</a></span><ul class="toc-item"><li><span><a href="#Upsampling" data-toc-modified-id="Upsampling-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Upsampling</a></span><ul class="toc-item"><li><span><a href="#Random-forest-model" data-toc-modified-id="Random-forest-model-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Random forest model</a></span></li><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Logistic regression</a></span></li><li><span><a href="#Nearest-Neighbors" data-toc-modified-id="Nearest-Neighbors-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Nearest Neighbors</a></span></li><li><span><a href="#SVC" data-toc-modified-id="SVC-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>SVC</a></span></li></ul></li><li><span><a href="#Downsampling" data-toc-modified-id="Downsampling-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Downsampling</a></span><ul class="toc-item"><li><span><a href="#Random-forest-model" data-toc-modified-id="Random-forest-model-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Random forest model</a></span></li><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Logistic regression</a></span></li><li><span><a href="#Nearest-Neighbors" data-toc-modified-id="Nearest-Neighbors-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Nearest Neighbors</a></span></li><li><span><a href="#SVC" data-toc-modified-id="SVC-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>SVC</a></span></li></ul></li></ul></li><li><span><a href="#Тестирование-лучшей-модели" data-toc-modified-id="Тестирование-лучшей-модели-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Тестирование лучшей модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# ## Введение
#
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Вам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Постройте модель с предельно большим значением F1-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59. Проверьте F1-меру на тестовой выборке самостоятельно.
#
# Дополнительно измеряйте AUC-ROC, сравнивайте её значение с F1-мерой.
#
#
# В ходе проект а мы выполним следующие этапы.
#
# 1. Исследование данных
# 2. Преобработка данных
# 3. Обучение модели
# 4. Оптимизация модели
# 5. Тестирование модели
#
# На первом этапе будет проведена певичное ислледование данных для выяснения проблемгых мест.
#
# На втором этапе  будет проведена предобработка данных. В ходе предобработки будут устранены пропуски данных, будет проведена категоризация признаков и масштабирование.
#
# На третьем этапе будет подобрана модель для исследования.
#
# На четвертом этапе будет проведена проверка на дисбаланс классов и оптимизирована модель машинного обучения.
#
# На пятом этапе будет проведено тестиорование выбраной модели и сделаны выводы о задаче исследования

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отличное введение 👍 Важно чтобы в проектах было подробное описание: когда потенциальные работодатели будут смотреть твой проект в портфолио, им нужно будет понимать задачу, чтобы можно было оценить её решение :)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# Рекомендую писать введение от первого лица множественного числа. Так работа выглядит более самостоятельной)
# </div>

# %%
# импорт функций

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# модели
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.dummy import DummyClassifier

# метрики
from sklearn.metrics import accuracy_score, f1_score 
from sklearn.metrics import roc_auc_score, roc_curve 
from sklearn.metrics import precision_recall_curve, classification_report
from sklearn.metrics import precision_score, recall_score

# работа с данными
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.utils import shuffle
from skimpy import skim, clean_columns

# pipeline
from imblearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Импорт выглядит отлично 👍
# </div>

# %% [markdown]
# ## Исследование данных

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# импорт датасета
try:
    df = pd.read_csv('uChurn.csv')
except:
    df = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# 1     1.0   83807.86              1          0               1
# 2     8.0  159660.80              3          1               0
# 3     1.0       0.00              2          0               0
# 4     2.0  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# **Признаки**
# - RowNumber — индекс строки в данных
# - CustomerId — уникальный идентификатор клиента
# - Surname — фамилия
# - CreditScore — кредитный рейтинг
# - Geography — страна проживания
# - Gender — пол
# - Age — возраст
# - Tenure — сколько лет человек является клиентом банка
# - Balance — баланс на счёте
# - NumOfProducts — количество продуктов банка, используемых клиентом
# - HasCrCard — наличие кредитной карты
# - IsActiveMember — активность клиента
# - EstimatedSalary — предполагаемая зарплата
#
# **Целевой признак**
# - Exited — факт ухода клиента

# %%
# приводим названия столбцов к конвенциональному виду

df = clean_columns(df)
# Out:
# 14 column names have been cleaned

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   row_number        10000 non-null  int64
#  1   customer_id       10000 non-null  int64
#  2   surname           10000 non-null  object
#  3   credit_score      10000 non-null  int64
#  4   geography         10000 non-null  object
#  5   gender            10000 non-null  object
#  6   age               10000 non-null  int64
#  7   tenure            9091 non-null   float64
#  8   balance           10000 non-null  float64
#  9   num_of_products   10000 non-null  int64
#  10  has_cr_card       10000 non-null  int64
#  11  is_active_member  10000 non-null  int64
#  12  estimated_salary  10000 non-null  float64
#  13  exited            10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Параметры row_number customer_id и surname не влияют на обучение модели их лучше удалить.
# Пропуски в параметре tenure тоже удалим, т.к. их нельзя восстановить по данным.

# %%
df = df.drop(['row_number', 'customer_id', 'surname'], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Удалить неинформативные признаки - хорошее решение 👍
# </div>

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9091 entries, 0 to 9998
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      9091 non-null   int64
#  1   geography         9091 non-null   object
#  2   gender            9091 non-null   object
#  3   age               9091 non-null   int64
#  4   tenure            9091 non-null   float64
#  5   balance           9091 non-null   float64
#  6   num_of_products   9091 non-null   int64
#  7   has_cr_card       9091 non-null   int64
#  8   is_active_member  9091 non-null   int64
#  9   estimated_salary  9091 non-null   float64
#  10  exited            9091 non-null   int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 852.3+ KB

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# Посмотри еще на такие варианты работы с пропусками:
#
# 1. Распределение по годам использования банка практически ровное, если сейчас заменить 909 пропусков медианой, то мы увеличим в 2 раза значение для 5 лет. Это кажется некорректным. Можно сделать заполнение пропусков случайными числами, тогда мы снизим влияние на наше распределение.
#
# 2. Так как значений в этом признаке ограниченное количество, можно сделать его категориальным признаком. Пропуски можно считать как за отдельную категорию (заполнить значением -1). Затем заменить тип данных Tenure на object и применить технику OHE.
#
# 3. Заполнить "0", считая, что это новые клиенты.
# </div>

# %%
df.describe().T
# Out:
#                    count           mean           std     min        25%  \
# credit_score      9091.0     650.736553     96.410471  350.00    584.000
# age               9091.0      38.949181     10.555581   18.00     32.000
# tenure            9091.0       4.997690      2.894723    0.00      2.000
# balance           9091.0   76522.740015  62329.528576    0.00      0.000
# num_of_products   9091.0       1.530195      0.581003    1.00      1.000
# has_cr_card       9091.0       0.704983      0.456076    0.00      0.000
# is_active_member  9091.0       0.515565      0.499785    0.00      0.000
# estimated_salary  9091.0  100181.214924  57624.755647   11.58  51227.745
# exited            9091.0       0.203938      0.402946    0.00      0.000
#
#                         50%        75%        max
# credit_score         652.00     717.00     850.00
# age                   37.00      44.00      92.00
# tenure                 5.00       7.00      10.00
# ...

# %% [markdown]
# Параметры geografy и gender перекодируем.

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data_ohe = pd.get_dummies(df, drop_first=True)
data_ohe.columns = data_ohe.columns.str.lower()

# %%
data_ohe.head()
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42     2.0       0.00                1            1
# 1           608   41     1.0   83807.86                1            0
# 2           502   42     8.0  159660.80                3            1
# 3           699   39     1.0       0.00                2            0
# 4           850   43     2.0  125510.82                1            1
#
#    is_active_member  estimated_salary  exited  geography_germany  \
# 0                 1         101348.88       1                  0
# 1                 1         112542.58       0                  0
# 2                 0         113931.57       1                  0
# 3                 0          93826.63       0                  0
# 4                 1          79084.10       0                  0
#
#    geography_spain  gender_male
# 0                0            0
# 1                1            0
# 2                0            0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# В данном случае это наиболее подходящий способ закодировать категориальные колонки 👍
# </div>

# %% [markdown]
# Проверим данные на мультиколлениарность

# %%
fig, ax = plt.subplots(figsize=(7, 7))

sns.heatmap(data_ohe.corr().round(2), 
            vmin=-1, 
            vmax=1, 
            annot=True, 
            annot_kws={'fontsize': 6,})
plt.title('Диаграмма корреляции', fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
sns.pairplot(data=data_ohe, hue='exited')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# **Вывод**
#
# Из данных были удалены не лишние столбцы(row_number customer_id и surname) и пропуски. Имена столюцов приведены к snake_case. Исследование показало отсутствие мультиколлениарности.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Ты хорошо владеешь методами первичного анализа данных 👍
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# На этом этапе данные будут разделены на обучающую и тестовую выборки, проведено мачштабирование и исследован дизбаланс классов.

# %%
# разделим данные на features и target 
target = data_ohe['exited']
features = data_ohe.drop('exited', axis=1)

# %%
display(target.shape, features.shape)
# Out:
# (9091,)
# (9091, 11)

# %%
# разделим данные в соотношение 1:4

X_train, X_test, Y_train, Y_test = train_test_split(features, target, test_size=0.20, random_state=123, stratify=target)

# %%
display(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (7272, 11)
# (1819, 11)
# (7272,)
# (1819,)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Данные поделены верно, пропорции выбраны адекватные 👍
# </div>

# %%
X_train.head()
# Out:
#       credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 9059           688   34     9.0   91025.58                2            0
# 4199           628   39     8.0  107553.33                1            1
# 9364           607   49     9.0  119960.29                2            1
# 6507           742   32     6.0  160485.16                1            1
# 876            502   32     1.0  173340.83                1            0
#
#       is_active_member  estimated_salary  geography_germany  geography_spain  \
# 9059                 1         163783.00                  1                0
# 4199                 0         117523.41                  0                1
# 9364                 0         103068.22                  0                0
# 6507                 0          29023.03                  0                0
# 876                  1         122763.95                  1                0
#
#       gender_male
# 9059            0
# 4199            0
# ...

# %%
# features_train[numeric] = scaler.transform(features_train[numeric])
# features_valid[numeric] = scaler.transform(features_valid[numeric]) 
X_train.columns
numeric = ['credit_score', 'age', 'tenure', 'balance', 'num_of_products', 'estimated_salary']

# %%
scaler = MinMaxScaler()
scaler.fit(X_train[numeric]) 

X_train[numeric] = scaler.transform(X_train[numeric])
X_test[numeric] = scaler.transform(X_test[numeric])

# %%
X_test.head()
# Out:
#       credit_score       age  tenure   balance  num_of_products  has_cr_card  \
# 1886         0.634  0.283784     0.7  0.667829              0.0            1
# 8122         0.428  0.472973     0.2  0.181238              0.0            1
# 4627         0.510  0.283784     0.7  0.000000              0.0            0
# 7119         0.542  0.175676     0.7  0.544678              0.0            1
# 9878         0.756  0.337838     0.8  0.511812              0.0            0
#
#       is_active_member  estimated_salary  geography_germany  geography_spain  \
# 1886                 1          0.205917                  0                1
# 8122                 1          0.205280                  0                0
# 4627                 1          0.596857                  0                0
# 7119                 1          0.743604                  0                0
# 9878                 1          0.695266                  0                1
#
#       gender_male
# 1886            1
# ...

# %%
X_train.head()
# Out:
#    credit_score       age  tenure   balance  num_of_products  has_cr_card  \
# 0         0.676  0.216216     0.9  0.362799         0.333333            0
# 1         0.556  0.283784     0.8  0.428673         0.000000            1
# 2         0.514  0.418919     0.9  0.478124         0.333333            1
# 3         0.784  0.189189     0.6  0.639643         0.000000            1
# 4         0.304  0.189189     0.1  0.690881         0.000000            0
#
#    is_active_member  estimated_salary  geography_germany  geography_spain  \
# 0                 1          0.819096                  1                0
# 1                 0          0.587730                  0                1
# 2                 0          0.515433                  0                0
# 3                 0          0.145100                  0                0
# 4                 1          0.613941                  1                0
#
#    gender_male
# 0            0
# 1            0
# 2            0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отлично, признаки масштабированы 👍 Не забыли, что fit нужно делать только на train выборке.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# Масштабирование стоит применить только для численных признаков
# </div>

# %% [markdown]
# Исследуем дизбаланс классов

# %%
Y_train.value_counts(normalize=1)
# Out:
# 0    0.796067
# 1    0.203933
# Name: exited, dtype: float64

# %%
Y_test.value_counts(normalize=1)
# Out:
# 0    0.796042
# 1    0.203958
# Name: exited, dtype: float64

# %% [markdown]
# **Вывод**
# Мы разделили выборку на обучающую и тестовую, отмасштабировали выборки. Исследование дизбаланса классов показало наличие сильного дизбаланса.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Виден явный дисбаланс классов в пользу отрицательного класса. Если мы будем всех людей прогнозировать, что они не уйдут из банка, то в 80% случаев мы будем правы.
# </div>

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Для первичного анализа используем несколько можлей машинного обучения и сравним получающуюся F1 метрику.

# %% [markdown]
# ### Random forest model

# %%
# Подготовим параметры для обучения.

rfc_param = {'n_estimators': range(10, 101, 10),
         'max_depth': range(5,20, 2),
         'min_samples_leaf': [1,10,20,30],
         }
rfc_model = RandomForestClassifier(random_state=123)

# используем gridserch для получения лучших параметров

rfc_grid = GridSearchCV(rfc_model, rfc_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
rfc_grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=123),
#              n_jobs=-1,
#              param_grid={'max_depth': range(5, 20, 2),
#                          'min_samples_leaf': [1, 10, 20, 30],
#                          'n_estimators': range(10, 101, 10)},
#              scoring='f1', verbose=1)

# %%
rfc_grid.best_params_
# Out:
# {'max_depth': 17, 'min_samples_leaf': 1, 'n_estimators': 90}

# %%
rfc_grid.best_score_
# Out:
# 0.5730262996226507

# %%
proba_rfc = rfc_grid.predict_proba(X_train)[:, 1]

roc_auc_score(Y_train, proba_rfc)
# Out:
# 0.9999891672617879

# %% [markdown]
# ### Logistic regression

# %%
lr_param = {'solver': ['liblinear'],
            'penalty': ['l1', 'l2']}

lr_model = LogisticRegression(random_state=12345)

lr_grid = GridSearchCV(lr_model, lr_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
lr_grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=12345), n_jobs=-1,
#              param_grid={'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='f1', verbose=1)

# %%
lr_grid.best_params_
# Out:
# {'penalty': 'l1', 'solver': 'liblinear'}

# %%
lr_grid.best_score_
# Out:
# 0.3114125382946689

# %%
proba_lr = lr_grid.predict_proba(X_train)[:, 1]

roc_auc_score(Y_train, proba_lr)
# Out:
# 0.7682965822012053

# %% [markdown]
# ### Nearest Neighbors

# %%
knn_param = {'n_neighbors': range(5,21,1)}

knn_model = KNeighborsClassifier()

knn_grid = GridSearchCV(knn_model, knn_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
knn_grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(5, 21)}, scoring='f1', verbose=1)

# %%
knn_grid.best_params_
# Out:
# {'n_neighbors': 5}

# %%
knn_grid.best_score_
# Out:
# 0.39571828670594106

# %%
proba_knn = knn_grid.predict_proba(X_train)[:, 1]

roc_auc_score(Y_train, proba_knn)
# Out:
# 0.9094849009683885

# %% [markdown]
# ### SVC

# %%
svm_param = {'kernel':['linear'],
            'probability': [True]}

svm_model = SVC(random_state=12345)

svm_grid = GridSearchCV(svm_model, svm_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
svm_grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5, estimator=SVC(random_state=12345), n_jobs=-1,
#              param_grid={'kernel': ['linear'], 'probability': [True]},
#              scoring='f1', verbose=1)

# %%
svm_grid.best_score_
# Out:
# 0.0

# %%
proba_svm = svm_grid.predict_proba(X_train)[:, 1]

roc_auc_score(Y_train, proba_svm)
# Out:
# 0.5321079448583339

# %%
svm_grid.scorer_
# Out:
# make_scorer(f1_score, average=binary)

# %% [markdown]
# **Вывод**
#
# На несбалансированной выборке лучше всего показала себя модель Случаного леса.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модели обучены корректно 👍 Молодец, что для подбора гиперпараметров используешь GridSearchCV
# </div>

# %% [markdown]
# ## Оптимизация

# %% [markdown]
# ### Upsampling

# %% [markdown]
# Избавимся от дизбаланса классов методом апсемплинга и проведем тесты повторно. Для апсемплинга будем использовать функцию SMOTE.

# %%
# смотрим на распределение классов
Y_train.plot(kind ='hist', bins=2, figsize=(1,1))
plt.title('Распределение классов', fontsize=8)
plt.show()

# %%
# отношение признаков
coef = Y_train.value_counts(normalize=1)[0] / Y_train.value_counts(normalize=1)[1]
print(coef)
# Out:
# 3.9035738368172623

# %%
X_train.reset_index(drop=True, inplace=True)
Y_train.reset_index(drop=True, inplace=True)

# %%
Y_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: exited, dtype: int64

# %% [markdown]
# #### Random forest model

# %%
# Подготовим параметры для обучения.

rfc_param = {'rfc__n_estimators': range(10, 101, 10),
             'rfc__max_depth': range(5,20, 2),
             'rfc__min_samples_leaf': [1,10,20,30],
             }
rfc_model = RandomForestClassifier(random_state=123)

# используем gridserch для получения лучших параметров

rfc_pipeline = Pipeline([('smt', SMOTE(random_state=123)), ('rfc', rfc_model)])

rfc_grid_up = GridSearchCV(rfc_pipeline, rfc_param, cv=5, scoring=['f1','roc_auc'], refit='f1', n_jobs=-1, verbose=1)
rfc_grid_up.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('smt', SMOTE(random_state=123)),
#                                        ('rfc',
#                                         RandomForestClassifier(random_state=123))]),
#              n_jobs=-1,
#              param_grid={'rfc__max_depth': range(5, 20, 2),
#                          'rfc__min_samples_leaf': [1, 10, 20, 30],
#                          'rfc__n_estimators': range(10, 101, 10)},
#              refit='f1', scoring=['f1', 'roc_auc'], verbose=1)

# %%
rfc_grid_up.best_params_
# Out:
# {'rfc__max_depth': 13, 'rfc__min_samples_leaf': 1, 'rfc__n_estimators': 60}

# %%
print('F1:',rfc_grid_up.best_score_)
# Out:
# F1: 0.6097799443013866

# %%
# ищем индекс лучшей оценки
def find_key(dictionary, value):
    ''' функция для поиска лучшей оценки в массиве кросс валидации
        
        аргументы:
        dictionary - словарь параметров обучения
        value - значение для поиска
        
        возвращаемое значение:
        (ключ значения, индекс значения)
    
    '''
    for key, item in dictionary.items():
        if value in item:
            return key, item.tolist().index(value)

# %%
rfc_m = find_key(rfc_grid_up.cv_results_, rfc_grid_up.best_score_)
print(rfc_m)
# находим значение roc_auc по индексу
print('ROC_AUC:', rfc_grid_up.cv_results_['mean_test_roc_auc'][rfc_m[1]])
# Out:
# ('mean_test_f1', 165)
# ROC_AUC: 0.8515157770989212

# %% [markdown]
# #### Logistic regression

# %%
lr_param = {'lr__solver': ['liblinear'],
            'lr__penalty': ['l1', 'l2']
           }

lr_model = LogisticRegression(random_state=12345)

lr_pipeline = Pipeline([('smt', SMOTE(random_state=123)), ('lr', lr_model)])

lr_grid_up = GridSearchCV(lr_pipeline, lr_param, cv=5, scoring=['f1','roc_auc'], refit='f1', n_jobs=-1, verbose=1)
lr_grid_up.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('smt', SMOTE(random_state=123)),
#                                        ('lr',
#                                         LogisticRegression(random_state=12345))]),
#              n_jobs=-1,
#              param_grid={'lr__penalty': ['l1', 'l2'],
#                          'lr__solver': ['liblinear']},
#              refit='f1', scoring=['f1', 'roc_auc'], verbose=1)

# %%
lr_grid_up.best_params_
# Out:
# {'lr__penalty': 'l1', 'lr__solver': 'liblinear'}

# %%
lr_grid_up.best_score_
# Out:
# 0.4984812138491

# %%
lr_m = find_key(lr_grid_up.cv_results_, lr_grid_up.best_score_)
print(lr_m)
# находим значение roc_auc по индексу
print('ROC_AUC:', lr_grid_up.cv_results_['mean_test_roc_auc'][lr_m[1]])
# Out:
# ('mean_test_f1', 0)
# ROC_AUC: 0.7689860522594701

# %% [markdown]
# #### Nearest Neighbors

# %%
knn_param = {'knn__n_neighbors': range(5,21,1)}

knn_model = KNeighborsClassifier()

knn_pipeline = Pipeline([('smt', SMOTE(random_state=123)), ('knn', knn_model)])

knn_grid_up = GridSearchCV(knn_pipeline, knn_param, cv=5, scoring=['f1','roc_auc'], refit='f1', n_jobs=-1, verbose=1)
knn_grid_up.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('smt', SMOTE(random_state=123)),
#                                        ('knn', KNeighborsClassifier())]),
#              n_jobs=-1, param_grid={'knn__n_neighbors': range(5, 21)},
#              refit='f1', scoring=['f1', 'roc_auc'], verbose=1)

# %%
knn_grid_up.best_params_
# Out:
# {'knn__n_neighbors': 16}

# %%
knn_grid_up.best_score_
# Out:
# 0.48221637401659756

# %%
knn_m = find_key(knn_grid_up.cv_results_, knn_grid_up.best_score_)
print(knn_m)
# находим значение roc_auc по индексу
print('ROC_AUC:', knn_grid_up.cv_results_['mean_test_roc_auc'][knn_m[1]])
# Out:
# ('mean_test_f1', 11)
# ROC_AUC: 0.7505104403599969

# %% [markdown]
# #### SVC

# %%
svm_param = {'svm__kernel':['linear'],
            'svm__probability': [True]
            }

svm_model = SVC(random_state=12345)

svm_pipeline = Pipeline([('smt', SMOTE(random_state=123)), ('svm', svm_model)])

svm_grid_up = GridSearchCV(svm_pipeline, svm_param, cv=5, scoring=['f1','roc_auc'], refit='f1', n_jobs=-1, verbose=1)
svm_grid_up.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('smt', SMOTE(random_state=123)),
#                                        ('svm', SVC(random_state=12345))]),
#              n_jobs=-1,
#              param_grid={'svm__kernel': ['linear'], 'svm__probability': [True]},
#              refit='f1', scoring=['f1', 'roc_auc'], verbose=1)

# %%
svm_grid_up.best_score_
# Out:
# 0.5037700148103156

# %%
svm_m = find_key(svm_grid_up.cv_results_, svm_grid_up.best_score_)
print(svm_m)
# находим значение roc_auc по индексу
print('ROC_AUC:', svm_grid_up.cv_results_['mean_test_roc_auc'][svm_m[1]])
# Out:
# ('mean_test_f1', 0)
# ROC_AUC: 0.7689954055961896

# %% [markdown]
# **Вывод**
#
# Все модели значительно улучшили качество после апсемплинга выборки.

# %% [markdown]
# ### Downsampling

# %% [markdown]
# Сравняем классы путем уменьшения размкра выборки и проведеи тесты заново.

# %%
Y_train.value_counts()
# Out:
# 0    5789
# 1    1483
# Name: exited, dtype: int64

# %% [markdown]
# Приведем классы к равному балансу

# %%
X_train_down = pd.concat([X_train[Y_train==0].sample(Y_train.value_counts()[1], random_state=123)] + \
                         [X_train[Y_train==1]]).reset_index(drop=True)
X_train_down.shape
# Out:
# (2966, 11)

# %%
Y_train_down = pd.concat([Y_train[Y_train==0].sample(Y_train.value_counts()[1], random_state=123)] + \
                         [Y_train[Y_train==1]]).reset_index(drop=True)
Y_train_down.shape
# Out:
# (2966,)

# %%
# смотрим на распределение классов
Y_train_down.plot(kind ='hist', bins=2, figsize=(1,1))
plt.title('Распределение классов', fontsize=8)
plt.show()

# %% [markdown]
# #### Random forest model

# %%
# Подготовим параметры для обучения.

rfc_param = {'n_estimators': range(10, 101, 10),
             'max_depth': range(5,20, 2),
             'min_samples_leaf': [1,10,20,30],
             }
rfc_model = RandomForestClassifier(random_state=123)

# используем gridserch для получения лучших параметров

rfc_grid_down = GridSearchCV(rfc_model, rfc_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
rfc_grid_down.fit(X_train_down, Y_train_down)
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=123),
#              n_jobs=-1,
#              param_grid={'max_depth': range(5, 20, 2),
#                          'min_samples_leaf': [1, 10, 20, 30],
#                          'n_estimators': range(10, 101, 10)},
#              scoring='f1', verbose=1)

# %%
rfc_grid_down.best_params_
# Out:
# {'max_depth': 11, 'min_samples_leaf': 10, 'n_estimators': 90}

# %%
rfc_grid_down.best_score_
# Out:
# 0.7585748987702458

# %%
proba_rfc = rfc_grid_down.predict_proba(X_train_down)[:, 1]

roc_auc_score(Y_train_down, proba_rfc)
# Out:
# 0.9230960551341821

# %% [markdown]
# #### Logistic regression

# %%
lr_param = {'solver': ['liblinear'],
            'penalty': ['l1', 'l2']
           }

lr_model = LogisticRegression(random_state=12345)

lr_grid_down = GridSearchCV(lr_model, lr_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
lr_grid_down.fit(X_train_down, Y_train_down)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(random_state=12345), n_jobs=-1,
#              param_grid={'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='f1', verbose=1)

# %%
lr_grid_down.best_params_
# Out:
# {'penalty': 'l1', 'solver': 'liblinear'}

# %%
lr_grid_down.best_score_
# Out:
# 0.697464860562749

# %%
proba_lr = lr_grid_down.predict_proba(X_train_down)[:, 1]

roc_auc_score(Y_train_down, proba_lr)
# Out:
# 0.7663940482583236

# %% [markdown]
# #### Nearest Neighbors

# %%
knn_param = {'n_neighbors': range(5,21,1)}

knn_model = KNeighborsClassifier()

knn_grid_down = GridSearchCV(knn_model, knn_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
knn_grid_down.fit(X_train_down, Y_train_down)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'n_neighbors': range(5, 21)}, scoring='f1', verbose=1)

# %%
knn_grid_down.best_params_
# Out:
# {'n_neighbors': 5}

# %%
knn_grid_down.best_score_
# Out:
# 0.6618480781708265

# %%
proba_knn = knn_grid_down.predict_proba(X_train_down)[:, 1]

roc_auc_score(Y_train_down, proba_knn)
# Out:
# 0.8705961335686215

# %% [markdown]
# #### SVC

# %%
svm_param = {'kernel':['linear'],
            'probability': [True]
            }

svm_model = SVC(random_state=12345)

svm_grid_down = GridSearchCV(svm_model, svm_param, cv=5, n_jobs=-1, verbose=1, scoring='f1')
svm_grid_down.fit(X_train_down, Y_train_down)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5, estimator=SVC(random_state=12345), n_jobs=-1,
#              param_grid={'kernel': ['linear'], 'probability': [True]},
#              scoring='f1', verbose=1)

# %%
svm_grid_down.best_score_
# Out:
# 0.6986523977832457

# %%
proba_svm = svm_grid_down.predict_proba(X_train_down)[:, 1]

roc_auc_score(Y_train_down, proba_svm)
# Out:
# 0.7672688764414317

# %%
svm_grid_down.scorer_
# Out:
# make_scorer(f1_score, average=binary)

# %%
# построим сравнительную таблицу метрики f1 
d = np.array([[rfc_grid.best_score_, rfc_grid_up.best_score_, rfc_grid_down.best_score_], 
               [lr_grid.best_score_, lr_grid_up.best_score_, lr_grid_down.best_score_], 
               [knn_grid.best_score_, knn_grid_up.best_score_, knn_grid_down.best_score_],
              [svm_grid.best_score_, svm_grid_up.best_score_, svm_grid_down.best_score_]])
table = pd.DataFrame(data=d, index=['rfc', 'lr', 'knn', 'svm'], columns=['unbalanced', 'upsampling', 'downsampling'])
table
# Out:
#      unbalanced  upsampling  downsampling
# rfc    0.573026    0.609780      0.758575
# lr     0.311413    0.498481      0.697465
# knn    0.395718    0.482216      0.661848
# svm    0.000000    0.503770      0.698652

# %%
print(table.to_markdown())
# Out:
# |     |   unbalanced |   upsampling |   downsampling |
# |:----|-------------:|-------------:|---------------:|
# | rfc |     0.573026 |     0.60978  |       0.758575 |
# | lr  |     0.311413 |     0.498481 |       0.697465 |
# | knn |     0.395718 |     0.482216 |       0.661848 |
# | svm |     0        |     0.50377  |       0.698652 |

# %% [markdown]
# **Вывод**
#
# Модели на сбалансированных выборках показывают лучшие результаты, чем на несбалансированной выборке.
# Лучше всех показывает себя модель случйного леса. Ее будем проверять на тестовой выборке.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# По модельной части замечаний нет!) Все этапы выполнены отлично 👍
# </div>

# %% [markdown]
# ## Тестирование лучшей модели

# %% [markdown]
# Лучшие результаты показала модель случайного леса. Лучшие параметры были подобраны на выборке сбалансированной методом downsampling. Проверим модель с этими параметрами на тестовой выборке.

# %%
model = rfc_grid_down.best_estimator_

# %%
f1_score(Y_test, model.predict(X_test))
# Out:
# 0.577449947312961

# %%
proba = model.predict_proba(X_test)[:, 1]

roc_auc_score(Y_test, proba)
# Out:
# 0.8544641926404669

# %%
print(accuracy_score(Y_test, model.predict(X_test)))
# Out:
# 0.7795492028587135

# %% [markdown]
# Полученный результат говорит, о том, что модель была сильно переобучена. Проверим параметры полученые на выборке сбалансированной методом upsampling.

# %%
model_up = rfc_grid_up.best_estimator_

# %%
f1_score(Y_test, model_up.predict(X_test))
# Out:
# 0.6157697121401753

# %%
proba = model_up.predict_proba(X_test)[:, 1]

roc_auc_score(Y_test, proba)
# Out:
# 0.8586990513916397

# %%
print(accuracy_score(Y_test, model_up.predict(X_test)))
# Out:
# 0.8312259483232546

# %%
print(recall_score(Y_test, model_up.predict(X_test)))
# Out:
# 0.6630727762803235

# %%
print(precision_score(Y_test, model_up.predict(X_test)))
# Out:
# 0.5747663551401869

# %% [markdown]
# Проверим финальную модель на адекватность.

# %%
# создадим костантную модель.

dummy_clf = DummyClassifier(strategy='most_frequent')
dummy_clf.fit(X_train, Y_train)
print(dummy_clf.score(X_test, Y_test))
# Out:
# 0.7960417811984607

# %% [markdown]
# Accuracy финальной модели 0.82, что выше, чем accuracy болванки. Модель прошла проверку на адекватность.

# %%
fpr, tpr, thresholds = roc_curve(Y_test, proba) 

plt.figure()
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отличный результат 👍
# </div>

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе исследования были выполнены все запанированные этапы.
#
# Обзор данных показал наличие пропусков. Стоки с пропусками были удалены. Также из данных были удалены не лишние столбцы(row_number customer_id и surname). Имена столюцов приведены к snake_case. Исследование показало отсутствие мультиколлениарности.
#
# На этапе подготовки данных мы разбили данные на обучающую и тестовую выборки. И затем отмасштабировали их.
#
# В ходе исследования было рассотрено 4 модели классификации.
# - Случайный лес
# - Линейная регрессия
# - Метод ближайших соседей
# - Метод опорных векторов
#
# Каждая модель была проверена на несбалансированной выборке, выборке сбалансированной методом upsampling и выборке сбалансированной методом downsmpling. Точность модели уточнялась методом кросс-валидации на 5 фолдах.
#
# Семплирование проводилось с помощью функции SMOTE в случае upsampling.
#
# Рузультаты тестов по метрике f1 сведены в таблицу:
#
# |     |   unbalanced |   upsampling |   downsampling |
# |:----|-------------:|-------------:|---------------:|
# | rfc |     0.574773 |     0.608456 |       0.75813  |
# | lr  |     0.312856 |     0.500231 |       0.69779  |
# | knn |     0.464867 |     0.529685 |       0.714738 |
# | svm |     0        |     0.504801 |       0.697936 |
#
#
# Лучший результат показала модель случайного леса.
#
# В ходе проверки на тестовой выборке были уточнены параметры модели. Модель с параметрами подобранными на выборке сбалансированной методом downsmpling показала высокую степень переобучения. Поэтому были выбраны параметры подобранные на выборке сбалансированной методом upsmpling.
#
#
# В ходе исследования была проверена адекватность лучшей модели. Поскольку модель показала точность выше константной, проверка была пройдена.
#
# Лучшая модель показала следующие результаты:
#
#  | Метрика | Оценка|
#  |:--------|------:|
#  |Точность:|   0.55|
#  |Полнота: |   0.63|
#  |f1 мера: |   0.62|
#  |roc-auc: |   0.86|
#
#
# Модель показала невысокую точность. Предсказать уход клиента точно можно чуть более, чем  в половине случаев.
# Показатель полноты выше показателя точности. Мы сможем выявить 2/3 всех уходящих клиентов.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Вывод соответствует исследованию 👍
# </div>

# %% [markdown]
# # <font color='orange'>Общее впечатление</font>
# * Этот проект выполнен очень хорошо
# * Видно, что приложено много усилий
# * Молодец, что структурируешь ноутбук, приятно проверять такие работы
# * У тебя чистый и лаконичный код
# * Мне было интересно читать твои промежуточные выводы
# * Твой уровень подачи материала находится на высоком уровне
# * Критических замечаний нет
# * Молодец, отличная работа!
# * Удачи в дальнейшем обучении 👋

# %% [markdown]
# # <font color='orange'>Рекомендации 🔥</font>
# * Анализ данных на python и pandas https://www.youtube.com/watch?v=dd3RcafdOQk&t=82s
# * Курс "Введение в машинное обучение" https://stepik.org/course/4852
# * Разумные способы кодирования категориальных данных для машинного обучения https://machinelearningmastery.ru/smarter-ways-to-encode-categorical-data-for-machine-learning-part-1-of-3-6dca2f71b159/
# * Статья про "непонятную" метрику ROC-AUC https://dyakonov.org/2017/07/28/auc-roc-площадь-под-кривой-ошибок/
# * Хочешь подтянуть математику для DS?) https://academy.stepik.org/math-for-data-science
# * Результаты обучения моделей можно визуализировать 😎 https://www.datatechnotes.com/2019/08/elasticnet-regression-example-in-python.html
# * В нашем деле нужно быть всегда в курсе всех новинок, новостей и тд, вот тут публикуют новости в области DS: https://www.infoq.com/data-analysis/news/
# * Всем аналитикам данных рекомендую книгу Даниела Канемана "Думай медленно, решай быстро"
